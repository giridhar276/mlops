# %% [markdown]
# # Nested Runs in MLflow: Practice Exercise
#
# Use this after the main notebook.

# %% [markdown]
# ## Tasks
#
# 1. Run the main complete use case notebook.
# 2. Open MLflow UI and find the same run that logged the model.
# 3. Verify the model artifact contains input example/signature.
# 4. Verify the registered model source points to that same run URI.
# 5. Change one parameter and rerun.

# %%
# Import MLflow.
import mlflow

# Use local tracking folder.
mlflow.set_tracking_uri("file:./mlruns")

# Search runs.
runs = mlflow.search_runs()

# Display recent runs.
display(runs.head())
